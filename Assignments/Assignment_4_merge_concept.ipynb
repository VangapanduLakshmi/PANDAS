# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("insurance_status.csv")

# %%
df1 = pd.read_csv("C:\\Users\\laxmi\\Downloads\\salaries_v1.csv")
# Out:
# C:\Users\laxmi\AppData\Local\Temp\ipykernel_7788\3190457352.py:1: DtypeWarning: Columns (3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("C:\\Users\\laxmi\\Downloads\\salaries_v1.csv")

# %%
df1.head()
# Out:
#    EmployeeId      EmployeeName                   JobTitle    BasePay  \
# 0      104185     Victor C Reed          Recreation Leader   14568.75
# 1       74321  Margarita M Hill           Registered Nurse   142425.0
# 2       66309           John Li             Police Officer    17085.0
# 3       50793     Tyrone Harper  EMT/Paramedic/Firefighter   78505.61
# 4        4271     DEIRDRE APPEL         ASSOCIATE ENGINEER  129497.66
#
#   OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 0         0.0     367.2   3772.81   14935.95          18708.76  2013    NaN
# 1      3798.0  33841.12   47952.6  180064.12         228016.72  2013    NaN
# 2         0.0       0.0   6888.15   17085.00          23973.15  2012    NaN
# 3      4805.8   4877.92  26978.16   88189.33         115167.49  2012    NaN
# 4         0.0       0.0       NaN  129497.66         129497.66  2011    NaN
#
#           Agency Status
# 0  San Francisco    NaN
# 1  San Francisco    NaN
# ...

# %%
columns = [col.strip().lower() for col in df1.columns]

# %%
df1.columns = columns

# %%
df1.head()
# Out:
#    employeeid      employeename                   jobtitle    basepay  \
# 0      104185     Victor C Reed          Recreation Leader   14568.75
# 1       74321  Margarita M Hill           Registered Nurse   142425.0
# 2       66309           John Li             Police Officer    17085.0
# 3       50793     Tyrone Harper  EMT/Paramedic/Firefighter   78505.61
# 4        4271     DEIRDRE APPEL         ASSOCIATE ENGINEER  129497.66
#
#   overtimepay  otherpay  benefits   totalpay  totalpaybenefits  year  notes  \
# 0         0.0     367.2   3772.81   14935.95          18708.76  2013    NaN
# 1      3798.0  33841.12   47952.6  180064.12         228016.72  2013    NaN
# 2         0.0       0.0   6888.15   17085.00          23973.15  2012    NaN
# 3      4805.8   4877.92  26978.16   88189.33         115167.49  2012    NaN
# 4         0.0       0.0       NaN  129497.66         129497.66  2011    NaN
#
#           agency status
# 0  San Francisco    NaN
# 1  San Francisco    NaN
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   employeeid        148654 non-null  int64
#  1   employeename      148654 non-null  object
#  2   jobtitle          148654 non-null  object
#  3   basepay           148049 non-null  object
#  4   overtimepay       148654 non-null  object
#  5   otherpay          148654 non-null  object
#  6   benefits          112495 non-null  object
#  7   totalpay          148654 non-null  float64
#  8   totalpaybenefits  148654 non-null  float64
#  9   year              148654 non-null  int64
#  10  notes             0 non-null       float64
#  11  agency            148654 non-null  object
#  12  status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# **Who got the maximum salary?**

# %%
df1.loc[df1["totalpay"] == df1["totalpay"].max()]
# Out:
#        employeeid    employeename  \
# 98822           1  NATHANIEL FORD
#
#                                              jobtitle    basepay overtimepay  \
# 98822  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
#
#         otherpay benefits   totalpay  totalpaybenefits  year  notes  \
# 98822  400184.25      NaN  567595.43         567595.43  2011    NaN
#
#               agency status
# 98822  San Francisco    NaN

# %% [markdown]
# **What is the average pay without benefits?**

# %%
df1["basepay"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df1["basepay"].mean()
#
# File ~\anaconda3\envs\Datascience\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\envs\Datascience\Lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
# ...

# %% [markdown]
# **Here the problem is the basepay feture contains both float and string data types 😱**

# %%
df1 =df1.replace("Not Provided", np.nan).replace("Not provided", np.nan)

# %%
df1.loc[(df1["otherpay"] == "Not Provided") | (df1["otherpay"] == "Not provided")]
# Out:
# Empty DataFrame
# Columns: [employeeid, employeename, jobtitle, basepay, overtimepay, otherpay, benefits, totalpay, totalpaybenefits, year, notes, agency, status]
# Index: []

# %% [markdown]
# **What is the average pay without benefits?**

# %%
# there are two ways for to convert one data type to other datatype
# 1. using astype
# 2. using apply
df1["basepay"] = df1["basepay"].astype(float)

# %%
df1["basepay"].apply(pd.to_numeric)
# Out:
# 0          14568.75
# 1         142425.00
# 2          17085.00
# 3          78505.61
# 4         129497.66
#             ...
# 148649     72155.68
# 148650    112421.45
# 148651    149755.35
# 148652     56439.23
# 148653     57380.74
# Name: basepay, Length: 148654, dtype: float64

# %%
df1["basepay"].mean()
# Out:
# 66325.44884048769

# %% [markdown]
# **What is the highest base pay in the dataset?**

# %%
df1["basepay"].max()
# Out:
# 319275.01

# %% [markdown]
# **What is the job title of person who got the maximum over time pay?**

# %%
df1["overtimepay"] = df1["overtimepay"].apply(pd.to_numeric)

# %%
df1.loc[df1["overtimepay"] == df1["overtimepay"].max()]
# Out:
#        employeeid  employeename                         jobtitle    basepay  \
# 90636           2  GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02
#
#        overtimepay   otherpay benefits   totalpay  totalpaybenefits  year  \
# 90636    245131.88  137811.38      NaN  538909.28         538909.28  2011
#
#        notes         agency status
# 90636    NaN  San Francisco    NaN

# %% [markdown]
# **In which year was the average total pay (without benefits) of employees maximum?**

# %%
grp = df1.groupby("year")

# %%
grp["basepay"].mean()
# Out:
# year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: basepay, dtype: float64

# %% [markdown]
# **How many unique jobs are there?**

# %%
df1["jobtitle"].nunique()
# Out:
# 2158

# %% [markdown]
# **What are the top 5 most common jobs in the year 2014?**

# %%
df1.loc[df1["year"] == 2014, "jobtitle"].value_counts()
# Out:
# jobtitle
# Transit Operator                2479
# Special Nurse                   1478
# Registered Nurse                1234
# Public Svc Aide-Public Works     916
# Firefighter                      815
#                                 ...
# IS Trainer-Senior                  1
# Field Svcs Asst Supv               1
# Senior Morgue Attendant            1
# Plumber Supervisor 2               1
# Roofer Supervisor 1                1
# Name: count, Length: 996, dtype: int64

# %% [markdown]
# **How many people have the word Chief in their job title?**

# %%
chief_jobs = df1["jobtitle"].str.contains("chief", case =False, na = False)

# %%
df1[chief_jobs]
# Out:
#         employeeid      employeename                        jobtitle  \
# 137            517     VICKI CLAYTON      ASSISTANT CHIEF ATTORNEY I
# 446          42532  Nerivaldo Santos     Chief Fire Alarm Dispatcher
# 715          88304  Jennifer L Novak                     Chief Clerk
# 1136         94770    Jamie  Padover       Chief Stationary Engineer
# 1150         87018      Kelly M Toth                 Chief Dietitian
# ...            ...               ...                             ...
# 147873       36477     Victor Wyrsch  Battlion Chief, Fire Suppressi
# 148151         522     OWEN CLEMENTS      ASSISTANT CHIEF ATTORNEY I
# 148237       36611  Raemona Williams  Battlion Chief, Fire Suppressi
# 148241      117893   James T Struble       Chief Stationary Engineer
# 148403      110668           Ken Yee  Battalion Chief, Fire Suppress
#
#           basepay  overtimepay  otherpay  benefits   totalpay  \
# 137     185695.37         0.00       0.0       NaN  185695.37
# ...

# %% [markdown]
# **How many employees have an insurance?**

# %%
df.head()
# Out:
#    Unnamed: 0  emp_id  insurance_status
# 0           0       1                 0
# 1           1       2                 0
# 2           2       3                 0
# 3           3       4                 0
# 4           4       5                 0

# %%
df.drop(labels="Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#    emp_id  insurance_status
# 0       1                 0
# 1       2                 0
# 2       3                 0
# 3       4                 0
# 4       5                 0

# %%
# 0 represents the not having insurance, 1 represents the employees having insurance.
df["insurance_status"].value_counts()
# Out:
# insurance_status
# 0    146630
# 1      2024
# Name: count, dtype: int64

# %% [markdown]
# **What is the average total pay (without benefits) of employees with insurance?**

# %%
df.rename(columns={"emp_id":"employeeid"}, inplace =True)

# %%
df.head()
# Out:
#    employeeid  insurance_status
# 0           1                 0
# 1           2                 0
# 2           3                 0
# 3           4                 0
# 4           5                 0

# %%
df2 = pd.merge(df,df1,how="inner")

# %%
df2
# Out:
#         employeeid  insurance_status       employeename  \
# 0                1                 0     NATHANIEL FORD
# 1                2                 0       GARY JIMENEZ
# 2                3                 0     ALBERT PARDINI
# 3                4                 0  CHRISTOPHER CHONG
# 4                5                 0    PATRICK GARDNER
# ...            ...               ...                ...
# 148649      148650                 0      Roy I Tillery
# 148650      148651                 0                NaN
# 148651      148652                 0                NaN
# 148652      148653                 0                NaN
# 148653      148654                 0          Joe Lopez
#
#                                               jobtitle    basepay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# ...

# %%
df2.loc[df2["insurance_status"]==1, "totalpay"].mean()
# Out:
# 73387.96378952567

# %%
df2.pivot_table(values = "totalpay",
                  index = ["insurance_status"],
                  aggfunc=["mean"])
# Out:
#                           mean
#                       totalpay
# insurance_status
# 0                 74787.375678
# 1                 73387.963790
